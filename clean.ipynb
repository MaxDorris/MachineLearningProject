# %%
import pandas as pd

from IPython import display

# %%
file = 'Resources/stroke.csv'
stroke_df = pd.read_csv(file)
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
#     Attributes

# %%
display.Image('images/attributes.png')

# %%
# drop identifying (non-ordinal, non-nominal) columns
stroke_df.drop('id',axis=1,inplace=True)
stroke_df.sample(10)
# Out:
#       gender    age  hypertension  heart_disease ever_married      work_type  \
# 2835    Male  34.00             0              0          Yes        Private
# 2045    Male   2.00             0              0           No       children
# 2833  Female  41.00             0              0          Yes        Private
# 597   Female   1.08             0              0           No       children
# 759   Female  54.00             1              0           No        Private
# 4080  Female  34.00             0              0          Yes        Private
# 783     Male   2.00             0              0           No       children
# 1421    Male   9.00             0              0           No       children
# 3001    Male  33.00             0              0           No  Self-employed
# 4897  Female  77.00             0              0          Yes  Self-employed
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 2835          Urban              61.11  29.3     never smoked       0
# 2045          Rural              86.57  18.0          Unknown       0
# 2833          Urban              78.74  42.3           smokes       0
# 597           Rural              60.53  17.5          Unknown       0
# 759           Urban              97.06  28.5  formerly smoked       0
# 4080          Rural              89.31  37.3  formerly smoked       0
# 783           Urban              93.88  17.4          Unknown       0
# 1421          Urban              83.83  27.1          Unknown       0
# 3001          Rural              91.53  38.8  formerly smoked       0
# 4897          Rural              59.91  18.3     never smoked       0

# %%
stroke_df.stroke.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64
